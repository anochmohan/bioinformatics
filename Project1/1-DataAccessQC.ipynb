# %% [markdown]
# ![logo-gt.png](attachment:logo-gt.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>BIOS 4150/BIOL 6150</h1>
#     <h3>Instructor: Dr. King Jordan</h3>
#     <p>TAs: Shivam Sharma (shivamsharma13@gatech.edu) & Vishva Natarajan (vishvanata@gatech.edu)</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2>Project 1 (Data access & QC) starter notebook</h2>
#     <h3>Deadline: 12:00AM, October 20th, 2023</h3>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # **1. Your assigned 1000 Genomes individual**
# ### *Total Questions: 3*
# ### *Total Points: 10+10+20 = 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.1 Does you group have an assigned individual ID from the 1000 Genomes Project?</h3>
#     <p>Find the individual on the international genomes website and paste a screenshot below</p>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.2 What population does you assigned individual belong to?</h3>
#     <p>Write about where the geographical location of where this individual lived at the time of recruitment? </p>
# </div>

# %% [markdown]
#  The individual is of Mexican American ancestry and lived in Los Angeles at the time of recruitment.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>1.3 More about your individual's population?</h3>
#     <p>Read more about this population and write about their recent historical  (100-500 years) ancestors.</p>
# </div>

# %% [markdown]
# Mexican Americans have lived in the city of Los Angeles since the foundation of the city in the late 1700's. In recent history, US sponsored job contracts, threats of persecution, and the goal of a better future for their families, led to many mexican families moving to cities in the United States, including Los Angeles.

# %% [markdown]
# # **2. Exome sequencing**
# ### *Total Questions: 3*
# ### *Total Points: 20+20= 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.1 Does your assigned individual has exome sequencing data? If yes, then what is the SRR ID for that sequencing run?</h3>
#     <p>Does you individual have multiple SRR IDs? In case they do, which one would you pick? (Hint: The sequencing information is coming from the same individual; but larger file size might be more preferable)</p>
# </div>

# %% [markdown]
# Yes, our individual does have multiple SRR IDs. We are choosing to use the sequencing information from SRR058947. The files associated are roughly equal in length and are some of the largest exome sequence files.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>2.2 Looking at just the exome sequencing of this individual, how many variants would you expect them to carry compared to the reference genome?</h3>
#     <p>Keep in mind this is 1 individual, and learn about the expected number of variants from WGS, WES, and Genotyping</p>
# </div>

# %% [markdown]
# We would expect anything from thousands to tens of thousands of SNVs.

# %% [markdown]
# # **3. Data access**
# ### *Total Questions: 3*
# ### *Total Points: 20+20 = 40*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>3.1 Download the exome sequencing data for this individual and write the size of the files?</h3>
#     <p>3.1.1 How many files do you have? Is the sequencing paired?</p>
#     <p>3.1.2 How many reads are present in each file? </p>
# </div>

# %%
#Show you download commamd and ls the directory.
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19717/sequence_read/SRR058947_1.filt.fastq.gz
# !wget ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19717/sequence_read/SRR058947_2.filt.fastq.gz
# !ls -lh
# Out:
# --2023-10-19 18:24:37--  ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19717/sequence_read/SRR058947_1.filt.fastq.gz
#            => ‘SRR058947_1.filt.fastq.gz’
# Resolving ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)... 193.62.193.167
# Connecting to ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)|193.62.193.167|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/ftp/phase3/data/NA19717/sequence_read ... done.
# ==> SIZE SRR058947_1.filt.fastq.gz ... 2177417178
# ==> PASV ... done.    ==> RETR SRR058947_1.filt.fastq.gz ... done.
# Length: 2177417178 (2.0G) (unauthoritative)
#
# SRR058947_1.filt.fa 100%[===================>]   2.03G  31.0MB/s    in 81s
#
# 2023-10-19 18:26:00 (25.6 MB/s) - ‘SRR058947_1.filt.fastq.gz’ saved [2177417178]
#
# --2023-10-19 18:26:00--  ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19717/sequence_read/SRR058947_2.filt.fastq.gz
#            => ‘SRR058947_2.filt.fastq.gz’
# Resolving ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)... 193.62.193.167
# Connecting to ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)|193.62.193.167|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/ftp/phase3/data/NA19717/sequence_read ... done.
# ==> SIZE SRR058947_2.filt.fastq.gz ... 2239859881
# ==> PASV ... done.    ==> RETR SRR058947_2.filt.fastq.gz ... done.
# Length: 2239859881 (2.1G) (unauthoritative)
#
# SRR058947_2.filt.fa 100%[===================>]   2.09G  43.3MB/s    in 91s
#
# 2023-10-19 18:27:34 (23.5 MB/s) - ‘SRR058947_2.filt.fastq.gz’ saved [2239859881]
#
# total 4.2G
# -rw-r--r-- 1 cwijeyesekera3 gtperson 282K Oct 19 18:27 Project1-DataAccessQC.ipynb
# -rw-r--r-- 1 cwijeyesekera3 gtperson  48K Oct 18 14:04 Project2-ReadMapping.ipynb
# -rw-r--r-- 1 cwijeyesekera3 gtperson 2.1G Oct 19 18:26 SRR058947_1.filt.fastq.gz
# -rw-r--r-- 1 cwijeyesekera3 gtperson 2.1G Oct 19 18:27 SRR058947_2.filt.fastq.gz

# %%
# !echo $(zcat ~/biol6150-Local-Projects/SRR058947_1.filt.fastq.gz | wc -l)/4|bc
# !echo $(zcat ~/biol6150-Local-Projects/SRR058947_2.filt.fastq.gz | wc -l)/4|bc
# Out:
# 33759295
# 33759295

# %% [markdown]
# 3.1.1 How many files do you have? Is the sequencing paired?
# We have 2 files, and the sequencing is paired.
#
# 3.1.2 How many reads are present in each file?
# There are exactly 33759295 reads in each file.

# %% [markdown]
# # **4. Pre-QC with FastQC**
# ### *Total Questions: 2*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.1 Show your exact command below.</h3>
# </div>

# %%
#Command here.
# !fastqc -o ~/scratch/Data/Project1/fastQCBeforeTrimming ~/scratch/Data/Project1/SRR058947_1.filt.fastq.gz ~/scratch/Data/Project1/SRR058947_2.filt.fastq.gz
# Out:
# application/gzip
# application/gzip
# Started analysis of SRR058947_1.filt.fastq.gz
# Approx 5% complete for SRR058947_1.filt.fastq.gz
# Approx 10% complete for SRR058947_1.filt.fastq.gz
# Approx 15% complete for SRR058947_1.filt.fastq.gz
# Approx 20% complete for SRR058947_1.filt.fastq.gz
# Approx 25% complete for SRR058947_1.filt.fastq.gz
# Approx 30% complete for SRR058947_1.filt.fastq.gz
# Approx 35% complete for SRR058947_1.filt.fastq.gz
# Approx 40% complete for SRR058947_1.filt.fastq.gz
# Approx 45% complete for SRR058947_1.filt.fastq.gz
# Approx 50% complete for SRR058947_1.filt.fastq.gz
# Approx 55% complete for SRR058947_1.filt.fastq.gz
# Approx 60% complete for SRR058947_1.filt.fastq.gz
# Approx 65% complete for SRR058947_1.filt.fastq.gz
# Approx 70% complete for SRR058947_1.filt.fastq.gz
# Approx 75% complete for SRR058947_1.filt.fastq.gz
# Approx 80% complete for SRR058947_1.filt.fastq.gz
# Approx 85% complete for SRR058947_1.filt.fastq.gz
# Approx 90% complete for SRR058947_1.filt.fastq.gz
# Approx 95% complete for SRR058947_1.filt.fastq.gz
# Analysis complete for SRR058947_1.filt.fastq.gz
# Started analysis of SRR058947_2.filt.fastq.gz
# Approx 5% complete for SRR058947_2.filt.fastq.gz
# Approx 10% complete for SRR058947_2.filt.fastq.gz
# Approx 15% complete for SRR058947_2.filt.fastq.gz
# Approx 20% complete for SRR058947_2.filt.fastq.gz
# Approx 25% complete for SRR058947_2.filt.fastq.gz
# Approx 30% complete for SRR058947_2.filt.fastq.gz
# Approx 35% complete for SRR058947_2.filt.fastq.gz
# Approx 40% complete for SRR058947_2.filt.fastq.gz
# Approx 45% complete for SRR058947_2.filt.fastq.gz
# Approx 50% complete for SRR058947_2.filt.fastq.gz
# Approx 55% complete for SRR058947_2.filt.fastq.gz
# Approx 60% complete for SRR058947_2.filt.fastq.gz
# Approx 65% complete for SRR058947_2.filt.fastq.gz
# Approx 70% complete for SRR058947_2.filt.fastq.gz
# Approx 75% complete for SRR058947_2.filt.fastq.gz
# Approx 80% complete for SRR058947_2.filt.fastq.gz
# Approx 85% complete for SRR058947_2.filt.fastq.gz
# Approx 90% complete for SRR058947_2.filt.fastq.gz
# Approx 95% complete for SRR058947_2.filt.fastq.gz
# Analysis complete for SRR058947_2.filt.fastq.gz

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.2 Show <i>per base sequencing quality</i>?</h3>
#     <p>Add a screenshot below</p>
# </div>

# %% [markdown]
# SRR058947_1
# ![image.png](attachment:image.png)
#
# SRR058947_2
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>4.3 Show <i>Per base sequence content</i>?</h3>
#     <p>Add a screenshot below</p>
# </div>

# %% [markdown]
# SRR058947_1
# ![image.png](attachment:image.png)
#
# SRR058947_2
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # **5. Trimming with fastp or trimmmomatic**
# ### *Total Questions: 3*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.1 What was the tools and command you used?</h3>
#     <p>Write the tool name and exact command below</p>
# </div>

# %%
#Exact command here
# !fastp -i ~/scratch/Data/Project1/SRR058947_1.filt.fastq.gz -I ~/scratch/Data/Project1/SRR058947_2.filt.fastq.gz -o ~/scratch/Data/Project1/Trimming/SRR058947_1.Trimmed.fastq.gz -O ~/scratch/Data/Project1/Trimming/SRR058947_2.Trimmed.fastq.gz -f 10 -t 6
# Out:
# Read1 before filtering:
# total reads: 33759295
# total bases: 2565706420
# Q20 bases: 2321569891(90.4846%)
# Q30 bases: 2200820630(85.7783%)
#
# Read2 before filtering:
# total reads: 33759295
# total bases: 2565706420
# Q20 bases: 2287370621(89.1517%)
# Q30 bases: 2140603199(83.4313%)
#
# Read1 after filtering:
# total reads: 29514831
# total bases: 1768729602
# Q20 bases: 1741301970(98.4493%)
# Q30 bases: 1673522689(94.6172%)
#
# Read2 after filtering:
# total reads: 29514831
# total bases: 1768729602
# Q20 bases: 1731440440(97.8918%)
# Q30 bases: 1642201433(92.8464%)
#
# Filtering result:
# reads passed filter: 59029662
# reads failed due to low quality: 8484736
# reads failed due to too many N: 4192
# reads failed due to too short: 0
# reads with adapter trimmed: 596006
# bases trimmed due to adapters: 4441710
#
# Duplication rate: 1.59449%
#
# Insert size peak (evaluated by paired-end reads): 51
#
# JSON report: fastp.json
# HTML report: fastp.html
#
# fastp -i /home/hice1/cwijeyesekera3/scratch/Data/Project1/SRR058947_1.filt.fastq.gz -I /home/hice1/cwijeyesekera3/scratch/Data/Project1/SRR058947_2.filt.fastq.gz -o /home/hice1/cwijeyesekera3/scratch/Data/Project1/Trimming/SRR058947_1.Trimmed.fastq.gz -O /home/hice1/cwijeyesekera3/scratch/Data/Project1/Trimming/SRR058947_2.Trimmed.fastq.gz -f 10 -t 6
# fastp v0.23.4, time used: 141 seconds

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.2 How did you perform the trimming?</h3>
#     <p>Did you use dynamic built in features or hard coded parameters?</p>
#     <p>Did you have to go back and repeat the trimming after run(s) for <b>postQC?</b></p>
# </div>

# %% [markdown]
# #Write here
# We used hard coded parameters based on the per base sequence quality and content

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>5.3 What percentage of reads did you lose in the trimming process?</h3>
#     <p>5.3.1 Write the total number of reads before and after trimming</p>
#     <p>5.3.2 If you had a paired fastq file, are there any reads after trimming present in one file and not the other? (eg: present in reverse but not in forward?)</p>
#
# </div>

# %% [markdown]
# 5.3.1 Write the total number of reads before and after trimming <br />
# Before trimming:<br />
# SRR058947_1 - 33759295 reads <br />
# SRR058947_2 - 33759295 reads <br />
#
# After trimming:<br />
# SRR058947_1 - 29514831 reads <br />
# SRR058947_2 - 29514831 reads <br />
#
# 5.3.2 If you had a paired fastq file, are there any reads after trimming present in one file and not the other? (eg: present in reverse but not in forward?)  <br />
# No, the new files have the same reads present after trimming

# %% [markdown]
# # **6. Post-QC with FastQC?**
# ### *Total Questions: 2*
# ### *Total Points: 20+20+20 = 60*
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.1 Show your exact command below.</h3>
# </div>

# %%
# !fastqc -o ~/scratch/Data/Project1/fastQCAfterTrimming ~/scratch/Data/Project1/Trimming/SRR058947_1.Trimmed.fastq.gz ~/scratch/Data/Project1/Trimming/SRR058947_2.Trimmed.fastq.gz
# Out:
# application/gzip
# application/gzip
# Started analysis of SRR058947_1.Trimmed.fastq.gz
# Approx 5% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 10% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 15% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 20% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 25% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 30% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 35% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 40% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 45% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 50% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 55% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 60% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 65% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 70% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 75% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 80% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 85% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 90% complete for SRR058947_1.Trimmed.fastq.gz
# Approx 95% complete for SRR058947_1.Trimmed.fastq.gz
# Analysis complete for SRR058947_1.Trimmed.fastq.gz
# Started analysis of SRR058947_2.Trimmed.fastq.gz
# Approx 5% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 10% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 15% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 20% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 25% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 30% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 35% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 40% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 45% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 50% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 55% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 60% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 65% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 70% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 75% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 80% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 85% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 90% complete for SRR058947_2.Trimmed.fastq.gz
# Approx 95% complete for SRR058947_2.Trimmed.fastq.gz
# Analysis complete for SRR058947_2.Trimmed.fastq.gz

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.2 Show <i>per base sequencing quality</h3>
#     <p>If the quality was falling below 20 for certain regions then trim it. Add a screenshot below</p>
# </div>

# %% [markdown]
# SRR058947_1
# ![image.png](attachment:image.png)
#
# SRR058947_2
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3>6.3 Show <i>Per base sequence content</i>?</h3>
#     <p>Ideally we shouldn't see adapters at the beginning of the reads in the fastq files. Add a screenshot below</p>
# </div>

# %% [markdown]
# SRR058947_1
# ![image.png](attachment:image.png)
#
# SRR058947_2
# ![image-2.png](attachment:image-2.png)
